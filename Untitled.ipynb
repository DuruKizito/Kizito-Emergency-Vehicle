# %%
# Import the necessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Import the EfficientNet model
from tensorflow.keras.applications.efficientnet import EfficientNetB7 
from tensorflow.keras.applications.efficientnet import preprocess_input, decode_predictions # import the decode_predictions function

# %%
# Load the images and labels into a dataframe
data = []
labels = []
image_size = 600 # change the image size to match the model
for folder in ['emergency', 'non-emergency']:
    label = 1 if folder == 'emergency' else 0 
    for file in glob.glob(f'{folder}/*.jpg'): 
        image = cv2.imread(file) 
        image = cv2.resize(image, (image_size, image_size)) 
        data.append(image) 
        labels.append(label) 
data = np.array(data) / 255.0 
labels = np.array(labels) 
df = pd.DataFrame({'data': list(data), 'labels': labels}) 
df.head()
# Out:
#                                                 data  labels
# 0  [[[0.5529411764705883, 0.5254901960784314, 0.4...       1
# 1  [[[0.09411764705882353, 0.11372549019607843, 0...       1
# 2  [[[0.7607843137254902, 0.7019607843137254, 0.6...       1
# 3  [[[0.2196078431372549, 0.25882352941176473, 0....       1
# 4  [[[0.16470588235294117, 0.3333333333333333, 0....       1

# %%
# Split the dataframe into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['data'].tolist(), df['labels'].tolist(), test_size=0.2, shuffle=True, random_state=42) 
X_train = np.array(X_train) 
X_test = np.array(X_test) 
y_train = np.array(y_train) 
y_test = np.array(y_test) 
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1316, 600, 600, 3) (330, 600, 600, 3) (1316,) (330,)

# %%
# Define the CNN architecture
base_model = EfficientNetB7(input_shape=(image_size, image_size, 3), include_top=True, weights='imagenet') # use include_top=True to get the class names and probabilities
base_model.trainable = False 
model = tf.keras.models.Sequential() 
model.add(base_model) 
model.summary()
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 8c03f828fec3ef71311cd463b6759d99 so we will re-download the data.
# ...
# 268326632/268326632 [==============================] - 54s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnetb7 (Functional  (None, 1000)              66658687
#  )
#
# ...
# Total params: 66658687 (254.28 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 66658687 (254.28 MB)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]) # use sparse categorical crossentropy and accuracy for multi-class classification

# %%
# Train the model
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_sparse_categorical_accuracy', save_best_only=True, mode='max') # use val_sparse_categorical_accuracy as the monitor
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True) 
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint, earlystop])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 4
#       2 checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_sparse_categorical_accuracy', save_best_only=True, mode='max') # use val_sparse_categorical_accuracy as the monitor
#       3 earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# ----> 4 history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint, earlystop])
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ...

# %%
# Preprocess your images and videos
img = cv2.imread('ambulance.jpg') 
img = cv2.resize(img, (image_size, image_size)) 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
img = preprocess_input(img) 
plt.imshow(img)

# %%
#Video Demo
cap = cv2.VideoCapture('Emergency.mp4')
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        raise IOError("Cannot open video")

    
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN

# Define the class labels and a custom dictionary to map the model class names to the emergency or non-emergency labels
classLabels = ['non-emergency', 'emergency']
custom_dict = {'ambulance': 'emergency', 'fire_engine': 'emergency', 'police_car': 'emergency', 'taxi': 'non-emergency', 'car': 'non-emergency', 'truck': 'non-emergency', 'bus': 'non-emergency', 'motorcycle': 'non-emergency'}

while True:
    ret,frame = cap.read()
    
    
    frame = cv2.resize(frame, (image_size, image_size))
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = preprocess_input(frame) 
    frame = np.expand_dims(frame, axis=0) 
    pred = model.predict(frame) # get the probabilities
    pred = decode_predictions(pred, top=1)[0][0] # get the top 1 prediction
    class_name = pred[1] # get the class name
    class_prob = pred[2] # get the class probability
    label = custom_dict.get(class_name, 'unknown') # get the emergency or non-emergency label from the custom dictionary
    bbox = (0, 0, image_size, image_size) 
    
    print(label, class_name, class_prob)
   
    cv2.rectangle(frame, bbox, (255, 0, 0), 2)
    cv2.putText(frame, label, (bbox[0]+10, bbox[1]+40), font, fontScale=font_scale, color=(0, 255, 0), thickness=3)
                
    cv2.imshow('Kizito Object Detection', frame)
                
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

        
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 35363/35363 [==============================] - 0s 6us/step
# unknown nematode 0.010131004
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 36
#      33 cv2.rectangle(frame, bbox, (255, 0, 0), 2)
#      34 cv2.putText(frame, label, (bbox[0]+10, bbox[1]+40), font, fontScale=font_scale, color=(0, 255, 0), thickness=3)
# ---> 36 cv2.imshow('Kizito Object Detection', frame)
#      38 if cv2.waitKey(2) & 0xFF == ord('q'):
#      39     break
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:124: error: (-215:Assertion failed) bmi && width >= 0 && height >= 0 && (bpp == 8 || bpp == 24 || bpp == 32) in function 'FillBitmapInfo'
